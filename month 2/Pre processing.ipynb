# %%
import pandas as pd
import os
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Babatolatemi'

# %%
star_wars = pd.read_csv(r"C:\Users\Babatolatemi\Downloads\data-master\data-master\star-wars-survey\StarWars.csv", encoding="latin-1")

# %%
pd.set_option('display.max_columns', None) 
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
star_wars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 38 columns):
# RespondentID                                                                                                                                     1186 non-null float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     1187 non-null object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            837 non-null object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              674 non-null object
# Unnamed: 4                                                                                                                                       572 non-null object
# ...

# %%
star_wars.isnull().sum()
# Out:
# RespondentID                                                                                                                                       1
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                       0
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            350
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              513
# Unnamed: 4                                                                                                                                       615
# Unnamed: 5                                                                                                                                       636
# ...

# %%
star_wars.drop(star_wars.index[[0]], inplace=True)
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
# 5                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
cols_1_2 = ['Have you seen any of the 6 films in the Star Wars franchise?', 'Do you consider yourself to be a fan of the Star Wars film franchise?' ]
for col in cols_1_2:
    star_wars[col].value_counts().sum()

# %%
yes_no = {'Yes' : 'True',
         'No' : 'False',
         np.nan : 'False'}
for col in cols_1_2:
    star_wars[col] = star_wars[col].map(yes_no)
    
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
cols_3_8_titles = {'Which of the following Star Wars films have you seen? Please select all that apply.' : 'Seen_star_wars_1',
            'Unnamed: 4' : 'Seen_star_wars_2',
            'Unnamed: 5':'Seen_star_wars_3',
            'Unnamed: 6':'Seen_star_wars_4',
            'Unnamed: 7':'Seen_star_wars_5',
            'Unnamed: 8':'Seen_star_wars_6'}

star_wars = star_wars.rename(columns=cols_3_8_titles)
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#                            Seen_star_wars_1  \
# 1  Star Wars: Episode I  The Phantom Menace
# 2                                       NaN
# 3  Star Wars: Episode I  The Phantom Menace
# ...

# %%
star_wars = star_wars.rename(columns= {'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.' : 'ranking_1',
                                      'Unnamed: 10' : 'ranking_2', 
                                       'Unnamed: 11' : 'ranking_3', 
                                       'Unnamed: 12' : 'ranking_4',
                                      'Unnamed: 13' : 'ranking_5',
                                      'Unnamed: 14' : 'ranking_6'})

star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#                            Seen_star_wars_1  \
# 1  Star Wars: Episode I  The Phantom Menace
# 2                                       NaN
# 3  Star Wars: Episode I  The Phantom Menace
# ...

# %%
seen_notseen = {
    "Star Wars: Episode I  The Phantom Menace": True,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True,
    np.nan: False
}

for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(seen_notseen)
    
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#    Seen_star_wars_1  Seen_star_wars_2  Seen_star_wars_3  Seen_star_wars_4  \
# 1              True              True              True              True
# ...

# %%
star_wars = star_wars.rename(columns ={
        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.':'How do you view Luke Skywalker?',
        'Unnamed: 16':'How do you view Han solo?',
        'Unnamed: 17':'How do you view Princess Leia Organa?',
        'Unnamed: 18':'How do you view Obi Wan Kenobi?',
        'Unnamed: 19':'How do you view Yoda?',
        'Unnamed: 20':'How do you view R2 D2?',
        'Unnamed: 21':'How do you view C P30?',
        'Unnamed: 22':'How do you view Anamin skywalker?',
        'Unnamed: 23':'How do you view Darth skywalker?', 
        'Unnamed: 24':'How do you view Lando calrissian?',
        'Unnamed: 25':'How do you view Padme Amidala?',
        'Unnamed: 26':'How do you view Boba Fett?',
        'Unnamed: 27':'How do you view Emperor Palpatine?',
        'Unnamed: 28':'How do you view Jar jar binks?'})

star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#    Seen_star_wars_1  Seen_star_wars_2  Seen_star_wars_3  Seen_star_wars_4  \
# 1              True              True              True              True
# ...

# %%
views = {'Very favorably' : 'Very favorably',
        'Somewhat favorably' : 'Somewhat favorably',
        'Neither favorably nor unfavorably (neutral)':'Neutral',
        'Unfamiliar (N/A)': 'Unfamiliar (N/A)',
        np.nan : 'Unfamiliar (N/A)'}

for cols in star_wars.columns[15:29]:
    star_wars[cols] = star_wars[cols].map(views)
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#    Seen_star_wars_1  Seen_star_wars_2  Seen_star_wars_3  Seen_star_wars_4  \
# 1              True              True              True              True
# ...

# %%
yes_no = {'Yes' : 'True',
         'No' : 'False',
         np.nan : 'False'}
star_wars['Are you familiar with the Expanded Universe?'] = star_wars['Are you familiar with the Expanded Universe?'].map(yes_no)

# %%
yes_no = {'Yes' : 'True',
         'No' : 'False',
         np.nan : 'False'}
star_wars['Do you consider yourself to be a fan of the Expanded Universe?æ'] = star_wars['Do you consider yourself to be a fan of the Expanded Universe?æ'].map(yes_no)

# %%
yes_no = {'Yes' : 'True',
         'No' : 'False',
         np.nan : 'False'}
star_wars['Do you consider yourself to be a fan of the Star Trek franchise?'] = star_wars['Do you consider yourself to be a fan of the Star Trek franchise?'].map(yes_no)

# %%
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#    Seen_star_wars_1  Seen_star_wars_2  Seen_star_wars_3  Seen_star_wars_4  \
# 1              True              True              True              True
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ca08758f01ae> in <module>
# ----> 1 star_wars.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
